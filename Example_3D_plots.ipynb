# %%
# First import packages

import pandas as pd
import numpy as np
import pdb
import seaborn as sns
from matplotlib import pyplot as plt
import os

# %%
print("Pandas version {}".format(pd.__version__))
print("Numpy version {}".format(np.__version__))
print("Seaborn version {}".format(sns.__version__))
# Out:
# Pandas version 0.24.0
# Numpy version 1.17.0
# Seaborn version 0.9.0

# %%
#Set the color for each projection population

colors = sns.color_palette('muted', 10)

PFC_color = "#FFDB6E"
NAc_color = "#BF43CC"
LH_color = "#87FFE1"

# %%
#Change to directory containing .csv file
file_dir = 
os.chdir(file_dir)

# %%
#Load the .csv file for coronal CTB data
df = pd.read_csv("coronal_CTBLabelled_dataset.csv")
df.head(5)
# Out:
#    Unnamed: 0 animal    AP            x            y    intensity  area  \
# 0         360  RW264 -3.98  2352.627441  5365.019531  4728.944336  34.0
# 1         373  RW264 -3.98  2448.000000  5322.933105  6269.500000  20.0
# 2         375  RW264 -3.98  2471.238037  5316.190430  7364.125000  14.0
# 3         384  RW264 -3.98  2499.777832  5299.333496  7736.066895  36.0
# 4         385  RW264 -3.98  2305.650879  5296.444336  4544.866699  42.0
#
#       id    color  right.hemisphere        ML        DV  acronym  \
# 0  870.0  #4bb547             False  3.539341 -4.003632  SUBv-sp
# 1  870.0  #4bb547             False  3.459800 -3.965325  SUBv-sp
# 2  870.0  #4bb547             False  3.440583 -3.958985  SUBv-sp
# 3  870.0  #4bb547             False  3.417300 -3.946575  SUBv-sp
# 4  870.0  #4bb547             False  3.561050 -3.940325  SUBv-sp
#
#                                        name  \
# 0  Subiculum, ventral part, pyramidal layer
# 1  Subiculum, ventral part, pyramidal layer
# 2  Subiculum, ventral part, pyramidal layer
# 3  Subiculum, ventral part, pyramidal layer
# 4  Subiculum, ventral part, pyramidal layer
#
#                                              image  hemisphere Projection  \
# 0  10312019_14-49-42-Image Export-02_s11_AF647_ORG  RW264_left        NAc
# 1  10312019_14-49-42-Image Export-02_s11_AF647_ORG  RW264_left        NAc
# 2  10312019_14-49-42-Image Export-02_s11_AF647_ORG  RW264_left        NAc
# 3  10312019_14-49-42-Image Export-02_s11_AF647_ORG  RW264_left        NAc
# 4  10312019_14-49-42-Image Export-02_s11_AF647_ORG  RW264_left        NAc
#
#    Projection_cat
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
#See the column names containing the types of data
df.columns
# Out:
# Index(['Unnamed: 0', 'animal', 'AP', 'x', 'y', 'intensity', 'area', 'id',
#        'color', 'right.hemisphere', 'ML', 'DV', 'acronym', 'name', 'image',
#        'hemisphere', 'Projection', 'Projection_cat'],
#       dtype='object')

# %%
#Filter dataframe by projection type
df_subset_PFC = df[df.Projection == 'PFC']
df_subset_NAc = df[df.Projection == 'NAc']
df_subset_LH = df[df.Projection == 'LH']

# %%
#Plot the data in 3D
from mpl_toolkits.mplot3d import Axes3D

def white_bg_3d(ax):
    

    # make the grid lines transparent
    ax.xaxis._axinfo["grid"]['color'] =  (1,1,1,0)
    ax.yaxis._axinfo["grid"]['color'] =  (1,1,1,0)
    ax.zaxis._axinfo["grid"]['color'] =  (1,1,1,0)
    
fig = plt.figure(figsize = (7,10))
ax = Axes3D(fig)
white_bg_3d(ax)
ax.scatter(df_subset_PFC['AP'], 
           df_subset_PFC['ML'] ,
           df_subset_PFC['DV'], alpha = 0.1, label = 'PFC', s = 8, color = PFC_color)

ax.scatter(df_subset_NAc['AP'], 
           df_subset_NAc['ML'] ,
           df_subset_NAc['DV'], alpha = 0.1, label = 'NAc', s = 8, color = NAc_color)

ax.scatter(df_subset_LH['AP'], 
           df_subset_LH['ML'] ,
           df_subset_LH['DV'], alpha = 0.1, label = 'LH', s = 8, color = LH_color)

ax.set_xlabel("AP")
ax.set_ylabel("ML")
ax.set_zlabel("DV")

plt.legend(markerscale = 5)

# %%
#Load the .csv file for TRIO
df_trio = pd.read_csv("PFC_TRIO_cellcounts.csv")
df_trio.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  animal        AP            x            y  \
# 0           0             0  AMLeft -3.530200  2892.000000  4388.888672
# 1           1             1  AMLeft -3.695825  2720.533447  4383.466797
# 2           2             2  AMLeft -4.539575  1820.000000  4366.000000
# 3           3             3  AMLeft -3.133325  3268.000000  4103.111328
# 4           4             4  AMLeft -2.729158  3671.619141  4055.619141
#
#      intensity  area     id    color  right.hemisphere     ML        DV  \
# 0  2587.000000  12.0  502.0  #4fc244                 0  4.245 -4.673458
# 1  2334.666748  10.0  502.0  #4fc244                 0  4.245 -4.613041
# 2  2125.333252   8.0  664.0  #32b825                 0  4.245 -4.394291
# 3  4247.285645  12.0  407.0  #66a83d                 0  4.245 -4.438041
# 4  3694.500000  14.0  399.0  #7ed04b                 0  4.245 -4.435958
#
#   acronym                                               name  \
# 0     SUB                                          Subiculum
# 1     SUB                                          Subiculum
# 2   ENTm3  Entorhinal area, medial part, dorsal zone, lay...
# 3   CA1sp                         Field CA1, pyramidal layer
# 4   CA1so                          Field CA1, stratum oriens
#
#                                              image                 Coarse
# 0  2019_01_20__28438-Image Export-01_s09_mCher_ORG  Hippocampal formation
# 1  2019_01_20__28438-Image Export-01_s09_mCher_ORG  Hippocampal formation
# 2  2019_01_20__28438-Image Export-01_s09_mCher_ORG  Hippocampal formation
# 3  2019_01_20__28438-Image Export-01_s09_mCher_ORG  Hippocampal formation
# 4  2019_01_20__28438-Image Export-01_s09_mCher_ORG  Hippocampal formation

# %%
#Plot the data for PFC TRIO
fig = plt.figure(figsize = (7,10))
ax = Axes3D(fig)
white_bg_3d(ax)
ax.scatter(df_trio['AP'], 
           df_trio['ML'] ,
           df_trio['DV'], alpha = 0.1, s = 8, color = df_trio['color'])

ax.set_xlabel("AP")
ax.set_ylabel("ML")
ax.set_zlabel("DV")

ax.set_ylim(4,-4)
ax.set_xlim(-7,1)
ax.set_zlim(-8,-2)

plt.legend(markerscale = 5)
ax.set_aspect('equal')
# Out:
# No handles with labels found to put in legend.
